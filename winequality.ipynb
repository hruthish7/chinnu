# %% [markdown]
# <a href="https://colab.research.google.com/github/hruthish7/chinnu/blob/master/winequality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Hruthish Sreedhara - winequality.csv')

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# ...

# %%
fig = plt.figure(figsize = (15,8))
plt.xlabel('quality', fontsize = 20)
plt.ylabel('fixed acidity',fontsize=20)
plt.bar(data['quality'], data['fixed acidity'], color = 'green',)
# Out:
# <BarContainer object of 1599 artists>

# %%
fig = plt.figure(figsize = (15,8))
plt.xlabel('quality', fontsize = 20)
plt.ylabel('alcohol',fontsize=20)
plt.bar(data['quality'], data['alcohol'], color = 'green',)
# Out:
# <BarContainer object of 1599 artists>

# %%
fig = plt.figure(figsize = (15,8))
plt.xlabel('quality', fontsize = 20)
plt.ylabel('chlorides',fontsize=20)
plt.bar(data['quality'], data['chlorides'], color = 'green',)
# Out:
# <BarContainer object of 1599 artists>

# %%
fig = plt.figure(figsize = (15,8))
plt.xlabel('quality', fontsize = 20)
plt.ylabel('citric acid',fontsize=20)
plt.bar(data['quality'], data['citric acid'], color = 'green',)
# Out:
# <BarContainer object of 1599 artists>

# %%
fig = plt.figure(figsize = (15,8))
plt.xlabel('quality', fontsize = 20)
plt.ylabel('density',fontsize=20)
plt.bar(data['quality'], data['density'], color = 'green',)
# Out:
# <BarContainer object of 1599 artists>

# %%
fig = plt.figure(figsize = (15,8))
plt.xlabel('quality', fontsize = 20)
plt.ylabel('free sulfur dioxide',fontsize=20)
plt.bar(data['quality'], data['free sulfur dioxide'], color = 'green',)
# Out:
# <BarContainer object of 1599 artists>

# %%
fig = plt.figure(figsize = (15,8))
plt.xlabel('quality', fontsize = 20)
plt.ylabel('pH',fontsize=20)
plt.bar(data['quality'], data['pH'], color = 'green',)
# Out:
# <BarContainer object of 1599 artists>

# %%
fig = plt.figure(figsize = (15,8))
plt.xlabel('quality', fontsize = 20)
plt.ylabel('residual sugar',fontsize=20)
plt.bar(data['quality'], data['residual sugar'], color = 'green',)
# Out:
# <BarContainer object of 1599 artists>

# %%
fig = plt.figure(figsize = (15,8))
plt.xlabel('quality', fontsize = 20)
plt.ylabel('sulphates',fontsize=20)
plt.bar(data['quality'], data['sulphates'], color = 'green',)
# Out:
# <BarContainer object of 1599 artists>

# %%
fig = plt.figure(figsize = (15,8))
plt.xlabel('quality', fontsize = 20)
plt.ylabel('total sulfur dioxide',fontsize=20)
plt.bar(data['quality'], data['total sulfur dioxide'], color = 'green',)
# Out:
# <BarContainer object of 1599 artists>

# %%
fig = plt.figure(figsize = (15,8))
plt.xlabel('quality', fontsize = 20)
plt.ylabel('volatile acidity',fontsize=20)
plt.bar(data['quality'], data['volatile acidity'], color = 'green',)
# Out:
# <BarContainer object of 1599 artists>

# %%
plt.xlabel('quality', fontsize = 20)
plt.ylabel('frequency',fontsize=20)
data['fixed acidity'].value_counts().plot(kind='bar', figsize = (25,8))
