# %% [markdown]
# <a href="https://colab.research.google.com/github/hruthish7/chinnu/blob/master/bitcoin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Hruthish Sreedhara - bitcoin.csv')

# %%
data
# Out:
#            Date     Open    High      Low    Close
# 0    01/01/2017   991.50  1000.0   969.01   969.01
# 1    02/01/2017  1014.00  1400.0   971.51  1060.00
# 2    03/01/2017  1006.59  1069.5  1006.59  1069.49
# 3    04/01/2017  1070.00  1240.0  1070.00  1210.00
# 4    05/01/2017  1210.00  1212.0   955.08  1068.00
# ..          ...      ...     ...      ...      ...
# 450         NaN      NaN     NaN      NaN      NaN
# 451         NaN      NaN     NaN      NaN      NaN
# 452         NaN      NaN     NaN      NaN      NaN
# 453         NaN      NaN     NaN      NaN      NaN
# 454         NaN      NaN     NaN      NaN      NaN
#
# [455 rows x 5 columns]

# %%
data1 = data[1:90]

# %%
data1['gross profit or loss']=data1['Open']-data1['Close']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data1
# Out:
#           Date     Open     High      Low    Close  gross profit or loss
# 1   02/01/2017  1014.00  1400.00   971.51  1060.00                -46.00
# 2   03/01/2017  1006.59  1069.50  1006.59  1069.49                -62.90
# 3   04/01/2017  1070.00  1240.00  1070.00  1210.00               -140.00
# 4   05/01/2017  1210.00  1212.00   955.08  1068.00                142.00
# 5   06/01/2017  1016.01  1080.00   931.00  1001.00                 15.01
# ..         ...      ...      ...      ...      ...                   ...
# 85  27/03/2017   999.99  1064.99   965.05  1064.99                -65.00
# 86  28/03/2017  1064.99  1119.99  1045.01  1108.00                -43.01
# 87  29/03/2017  1108.00  1108.00  1040.00  1067.00                 41.00
# 88  30/03/2017  1094.00  1096.40  1030.00  1078.00                 16.00
# 89  31/03/2017  1080.00  1092.00  1057.00  1090.00                -10.00
#
# [89 rows x 6 columns]

# %%
import numpy as np

# %%
x_values = data1['Date']

# %%
x_values
# Out:
# 1     02/01/2017
# 2     03/01/2017
# 3     04/01/2017
# 4     05/01/2017
# 5     06/01/2017
#          ...
# 85    27/03/2017
# 86    28/03/2017
# 87    29/03/2017
# 88    30/03/2017
# 89    31/03/2017
# Name: Date, Length: 89, dtype: object

# %%
y_values = data1['gross profit or loss']

# %%
y_values
# Out:
# 1     -46.00
# 2     -62.90
# 3    -140.00
# 4     142.00
# 5      15.01
#        ...
# 85    -65.00
# 86    -43.01
# 87     41.00
# 88     16.00
# 89    -10.00
# Name: gross profit or loss, Length: 89, dtype: float64

# %%
plt.figure(figsize=(25,10))
plt.xlabel('Date', fontsize = 20)
plt.ylabel('gross profit or loss',fontsize=20)
plt.title('bitcoin',fontsize=20)
plt.xticks(rotation=70,fontsize=12)
plt.yticks(fontsize=15)
plt.plot( x_values, y_values, marker='o', markerfacecolor='blue', markersize=5, color='skyblue', linewidth=1)
plt.savefig('foo1.png',transparent = True)
